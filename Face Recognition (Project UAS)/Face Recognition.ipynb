# %% [markdown]
# ## Image Recognition
# - Menggunakan BPNN dengan PCA
# - Menggunakan CNN dengan Normalisasi Data
# ### Anggota Kelompok:
# - Arief Saferman
# - Kevin Darmawan
# - Ramadhan Kalih Sewu
# - Yogie Wisesa

# %%
import time

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
seed = 1
img_h = 100
img_w = 100
batch_size = 32
data_dir = 'FotoAI2020'

train_set = tf.keras.preprocessing.image_dataset_from_directory(
    directory=data_dir,
    validation_split=0.3,
    subset='training',
    batch_size=batch_size,
    color_mode='grayscale',
    image_size=(img_h, img_w),
    seed=seed
)
# Out:
# Found 420 files belonging to 43 classes.
# Using 294 files for training.

# %%
test_set = tf.keras.preprocessing.image_dataset_from_directory(
    directory=data_dir,
    validation_split=0.3,
    subset='validation',
    batch_size=batch_size,
    color_mode='grayscale',
    image_size=(img_h, img_w),
    seed=seed
)
# Out:
# Found 420 files belonging to 43 classes.
# Using 126 files for validation.

# %%
classes = train_set.class_names
print(classes)
# Out:
# ['AAA', 'ABI', 'AFI', 'AGH', 'AIL', 'ARL', 'ASA', 'BDL', 'DIA', 'DIO', 'DRA', 'EZA', 'FAR', 'FMR', 'FRS', 'GLA', 'GPS', 'HMA', 'HZR', 'IDR', 'KDA', 'MAA', 'MAJ', 'MFA', 'MFH', 'MGN', 'MMF', 'MRF', 'MSA', 'MZA', 'MZB', 'NIS', 'QTH', 'RCK', 'RKS', 'SAD', 'SHE', 'SNN', 'SVD', 'SYH', 'SYN', 'YSS', 'ZHT']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_set.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i], cmap='gray')
    plt.title(classes[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_set:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 100, 100, 1)
# (32,)

# %%
train_set = train_set.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_set = test_set.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# Normalisasi data, mengubah satuan piksel (0-255) menjadi satuan decimal (0.0 - 1.0) agar mudah diolah oleh fungsi Neural Network

# %%
normalized_ds = train_set.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# ## CNN
# - Membangun Layer (Neuron)

# %%
num_classes = 43

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_h, img_w, 1)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 100, 100, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 16)      160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 1,208,619
# Trainable params: 1,208,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
class timecallback(tf.keras.callbacks.Callback):
    def __init__(self):
        self.times = []
        # use this value as reference to calculate cummulative time taken
        self.timetaken = time.time()
    def on_epoch_end(self,epoch,logs = {}):
        self.times.append((epoch, time.time() - self.timetaken))
    def on_train_end(self,logs = {}):
        plt.xlabel('Epoch')
        plt.ylabel('Total time taken until an epoch (sec)')
        plt.plot(*zip(*self.times))
        plt.show()
        print('Total Time to Epoch ', self.times[-1][0], ': ', self.times[-1][1], ' Seconds')

# %%
epochs = 20
timetaken = timecallback()
history = model.fit(
  train_set,
  validation_data=test_set,
  epochs=epochs,
  callbacks=timetaken
)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 90ms/step - loss: 3.7563 - accuracy: 0.0442 - val_loss: 3.7025 - val_accuracy: 0.1190
# Epoch 2/20
# 10/10 [==============================] - 1s 75ms/step - loss: 3.5500 - accuracy: 0.1939 - val_loss: 3.3856 - val_accuracy: 0.1667
# Epoch 3/20
# 10/10 [==============================] - 1s 75ms/step - loss: 2.8236 - accuracy: 0.3367 - val_loss: 2.2589 - val_accuracy: 0.3889
# Epoch 4/20
# 10/10 [==============================] - 1s 74ms/step - loss: 1.4865 - accuracy: 0.6259 - val_loss: 1.1279 - val_accuracy: 0.7063
# Epoch 5/20
# 10/10 [==============================] - 1s 75ms/step - loss: 0.5499 - accuracy: 0.8469 - val_loss: 0.5369 - val_accuracy: 0.8333
# Epoch 6/20
# 10/10 [==============================] - 1s 75ms/step - loss: 0.1949 - accuracy: 0.9558 - val_loss: 0.5137 - val_accuracy: 0.8571
# Epoch 7/20
# 10/10 [==============================] - 1s 75ms/step - loss: 0.1509 - accuracy: 0.9558 - val_loss: 0.4291 - val_accuracy: 0.9048
# Epoch 8/20
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0449 - accuracy: 0.9932 - val_loss: 0.2430 - val_accuracy: 0.9365
# Epoch 9/20
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0363 - accuracy: 0.9932 - val_loss: 0.4485 - val_accuracy: 0.8889
# Epoch 10/20
# 10/10 [==============================] - 1s 74ms/step - loss: 0.0530 - accuracy: 0.9898 - val_loss: 0.3770 - val_accuracy: 0.9048
# Epoch 11/20
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0209 - accuracy: 0.9966 - val_loss: 0.3845 - val_accuracy: 0.9206
# Epoch 12/20
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0150 - accuracy: 0.9966 - val_loss: 0.3199 - val_accuracy: 0.9286
# Epoch 13/20
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.3898 - val_accuracy: 0.9206
# Epoch 14/20
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3380 - val_accuracy: 0.9286
# Epoch 15/20
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3238 - val_accuracy: 0.9365
# Epoch 16/20
# 10/10 [==============================] - 1s 77ms/step - loss: 8.8237e-04 - accuracy: 1.0000 - val_loss: 0.3195 - val_accuracy: 0.9365
# Epoch 17/20
# 10/10 [==============================] - 1s 80ms/step - loss: 6.2334e-04 - accuracy: 1.0000 - val_loss: 0.3196 - val_accuracy: 0.9444
# Epoch 18/20
# 10/10 [==============================] - 1s 77ms/step - loss: 5.1398e-04 - accuracy: 1.0000 - val_loss: 0.3213 - val_accuracy: 0.9444
# Epoch 19/20
# 10/10 [==============================] - 1s 89ms/step - loss: 4.5083e-04 - accuracy: 1.0000 - val_loss: 0.3234 - val_accuracy: 0.9444
# Epoch 20/20
# 10/10 [==============================] - 1s 85ms/step - loss: 4.0720e-04 - accuracy: 1.0000 - val_loss: 0.3255 - val_accuracy: 0.9444
# Total Time to Epoch  19 :  16.081649780273438  Seconds

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# simpan hasil akurasi untuk di plot
CNN_acc = (acc[-1], val_acc[-1])

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# BPNN

# %% [markdown]
# ## PCA - Reduksi Fitur
# - Ubah ke Format Numpy Array dari Tensorflow data.Dataset agar dapat diolah oleh Sklearn PCA

# %%
def tfds_to_numpy(ds):
    ret = None
    lab = None
    for image, label in tfds.as_numpy(ds):
        if (ret is None):
            ret = image
            lab = label
        else:
            ret = np.append(ret, image, axis=0)
            lab = np.append(lab, label)
    return ret, lab.flatten()

reshape2 = (lambda arr: arr.reshape(arr.shape[0], arr.shape[1] * arr.shape[2]))

x_train_np, y_train_np = tfds_to_numpy(train_set)
x_test_np, y_test_np = tfds_to_numpy(test_set)


x_train_np = reshape2(x_train_np)
x_test_np = reshape2(x_test_np)

print(x_train_np.shape)
print(y_train_np.shape)
# Out:
# (294, 10000)
# (294,)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(x_train_np)
X_test_scaled = scaler.transform(x_test_np)

# %%
pca = PCA(n_components=200, whiten=True)
pca.fit(X_train_scaled)
X_pca_train = pca.fit_transform(X_train_scaled)
X_pca_test = pca.transform(X_test_scaled)
pca_std = np.std(X_pca_train)

print(X_pca_train.shape)
# Out:
# (294, 200)

# %% [markdown]
# ## Membangun BPNN Layer
# - Relu - Relu - Relu - Sigmoid

# %%
model = Sequential([
    keras.layers.Flatten(),
    keras.layers.GaussianNoise(pca_std),
    keras.layers.Dense(units=512, activation='relu'),
    keras.layers.Dense(units=256, activation='relu'),
    keras.layers.Dense(units=128, activation='relu'),
    keras.layers.Dense(units=num_classes, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
history = model.fit(
    x=X_pca_train,
    y=y_train_np,
    validation_data=(X_pca_test, y_test_np),
    epochs=epochs,
    callbacks=timetaken
)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 13ms/step - loss: 3.9051 - accuracy: 0.0170 - val_loss: 3.6593 - val_accuracy: 0.0794
# Epoch 2/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5461 - accuracy: 0.0952 - val_loss: 3.5646 - val_accuracy: 0.1587
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2617 - accuracy: 0.1973 - val_loss: 3.3803 - val_accuracy: 0.2540
# Epoch 4/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9521 - accuracy: 0.3061 - val_loss: 3.1141 - val_accuracy: 0.3968
# Epoch 5/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4725 - accuracy: 0.4932 - val_loss: 2.7670 - val_accuracy: 0.5159
# Epoch 6/20
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9643 - accuracy: 0.5782 - val_loss: 2.3059 - val_accuracy: 0.6746
# Epoch 7/20
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4616 - accuracy: 0.6939 - val_loss: 1.9404 - val_accuracy: 0.6984
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1103 - accuracy: 0.7653 - val_loss: 1.6633 - val_accuracy: 0.7460
# Epoch 9/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7507 - accuracy: 0.8741 - val_loss: 1.4464 - val_accuracy: 0.7619
# Epoch 10/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5203 - accuracy: 0.9184 - val_loss: 1.3172 - val_accuracy: 0.7778
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4112 - accuracy: 0.9286 - val_loss: 1.2261 - val_accuracy: 0.7619
# Epoch 12/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3014 - accuracy: 0.9388 - val_loss: 1.1629 - val_accuracy: 0.7778
# Epoch 13/20
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2750 - accuracy: 0.9558 - val_loss: 1.0934 - val_accuracy: 0.7857
# Epoch 14/20
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2368 - accuracy: 0.9558 - val_loss: 1.0836 - val_accuracy: 0.7857
# Epoch 15/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.9626 - val_loss: 0.9769 - val_accuracy: 0.8175
# Epoch 16/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2531 - accuracy: 0.9354 - val_loss: 0.9715 - val_accuracy: 0.8016
# Epoch 17/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1729 - accuracy: 0.9626 - val_loss: 0.9784 - val_accuracy: 0.8333
# Epoch 18/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.9626 - val_loss: 0.9290 - val_accuracy: 0.8095
# Epoch 19/20
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1272 - accuracy: 0.9796 - val_loss: 0.9167 - val_accuracy: 0.8175
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0982 - accuracy: 0.9830 - val_loss: 0.8802 - val_accuracy: 0.8333
# Total Time to Epoch  19 :  18.543267488479614  Seconds

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# simpan hasil akurasi untuk di plot
BPNN_acc = (acc[-1], val_acc[-1])

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Mantap!

# %%
fig = plt.figure(figsize = (10, 5))

xloc = ['CNN Training', 'CNN Validation',
        'BPNN Training', 'BPNN Validation']
yloc = [CNN_acc[0], CNN_acc[1],
        BPNN_acc[0], BPNN_acc[1]]
 
# creating the bar plot
mybar = plt.bar(xloc, yloc, color ='maroon', width = 0.4)

# Add counts above the two bar graphs
for rect in mybar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.3f}', ha='center', va='bottom')
 
plt.ylim(0.0, 1.1)
plt.xlabel("Algorithm")
plt.ylabel("Accuracy (Score)")
plt.title("CNN vs BPNN")
plt.show()

# %% [markdown]
# Akhirnya Kelar :V
